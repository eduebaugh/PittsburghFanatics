# %%
import pandas as pd
import geopandas
# %matplotlib inline
import matplotlib.pyplot as plt
#importing libraries

# %% [markdown]
# # Pittsburgh's Ballfields
#  ## For my portion of the project, I decided that for families, they would need a place to spend quality family time at. Baseball parks can provide this for them, whether their kid is on the team or they're looking to have a relaxing day, the ballfields can provide a fun day for all.
#  ### [click here for csv file used](https://data.wprdc.org/datastore/dump/9aa6f92f-aa06-48d2-8303-88b5bc398236)
#  ### [click here for shp file used](https://data.wprdc.org/dataset/e43ad211-523f-4f7d-8f96-e65d5a10a5df/resource/dbe634cd-a6ab-413b-a198-8ac695a84017/download/ballfields.zip)

# %% [markdown]
# ## Below is the data that I used

# %%
ballfields = pd.read_csv("ballfieldsData.csv") #reading the dataset
ballfields
# Out:
#       _id        field_name          x          y  objectid  area  perimeter  \
# 0    3301      McBride Park -79.907773  40.368990         1   0.0        0.0
# 1    3302    Carmalt School -80.006456  40.386580         2   0.0        0.0
# 2    3303         Sam Bryan -80.006881  40.389443         3   0.0        0.0
# 3    3304         Sam Bryan -80.007051  40.389711         4   0.0        0.0
# 4    3305  Brookline T-Ball -80.007183  40.390456         5   0.0        0.0
# ..    ...               ...        ...        ...       ...   ...        ...
# 125  3426  Brighton Heights -80.033498  40.488679       126   0.0        0.0
# 126  3427        Volunteers -79.994325  40.397489       127   NaN        NaN
# 127  3428        Volunteers -79.992973  40.398191       128   NaN        NaN
# 128  3429          Schenley -79.942339  40.433466       129   NaN        NaN
# 129  3430          Schenley -79.940774  40.433600       130   NaN        NaN
#
#      ballfields  ballfiel_1   id  polygonid  scale  angle       point_x  \
# 0           1.0         1.0   72        0.0    0.0    0.0  1.367323e+06
# 1           2.0         2.0   27        0.0    0.0    0.0  1.339998e+06
# 2           3.0         3.0   24        0.0    0.0    0.0  1.339906e+06
# 3           4.0         4.0   23        0.0    0.0    0.0  1.339862e+06
# 4           5.0         5.0   22        0.0    0.0    0.0  1.339832e+06
# ..          ...         ...  ...        ...    ...    ...           ...
# 125       126.0       126.0   15        0.0    0.0    0.0  1.333429e+06
# 126         NaN         NaN  113        NaN    NaN    NaN           NaN
# 127         NaN         NaN  112        NaN    NaN    NaN           NaN
# 128         NaN         NaN   97        NaN    NaN    NaN           NaN
# 129         NaN         NaN   98        NaN    NaN    NaN           NaN
#
#            point_y                                 dpw_name cityid active
# 0    384617.783181                                  Mcbride   P345    Yes
# 1    391710.738812                                  Carmalt   P299    Yes
# 2    392756.625499                             Sam Bryen #2   P394    Yes
# 3    392855.383504                             Sam Bryen #1   P296    Yes
# 4    393127.716293  Officer Stephen J. Mayhle Memorial Park   P295    Yes
# ..             ...                                      ...    ...    ...
# 125  429086.777248                       #1 Brighton Hights   P288    Yes
# 126            NaN                            Volunteers #4    NaN    Yes
# 127            NaN                            Volunteers #3    NaN    Yes
# 128            NaN                             Schenley # 2   P369    Yes
# 129            NaN                             Schenley # 3   P368    Yes
#
# [130 rows x 18 columns]

# %% [markdown]
# # This isn't very helpful, so lets change it to a graph so we can visualize it!

# %%
ballfieldsCounts= ballfields["field_name"].value_counts() #counting the field names
value_counts = ballfields["field_name"].value_counts() #creating variable value_counts 
filtered_counts = value_counts[value_counts > 2] #plotting only ballfields that have 3 or more
plt.figure(figsize=(10, 6)) #creating graph size to fit names
filtered_counts.plot(kind='bar') #creating a bar graph
plt.xticks(rotation=45) #rotating the names on the x axis to a 45 degree angle to prevent overlap
plt.xlabel('Field Names') #labeling the x axis as Field Names
plt.ylabel('# of ballfields') #labeling the y axis as # of ballfields
plt.title('Ballfields') #titling the graph as Ballfields
plt.tight_layout() #adjusts the size of the graph to fit the 10,6 parameters

# %% [markdown]
# ## Here, I have a bar graph that shows each of the top 6 ballfields. This however doesn't reflect the actual location of each field. To do that, we'll have to look at another graph

# %%
ballfieldsNb = pd.read_csv("ballfieldsData-Copy1.csv") #reads the file name and assigns it to variable ballfieldsNb
value_countsNb = ballfieldsNb["field_name"].value_counts() #assigns counting the field name values to variable value_countsNb
filtered_countsNb = value_countsNb[value_countsNb > 2] #plots only neighborhoods with 3 or more ballfields
plt.figure(figsize=(10, 6))  #creating graph size to fit names
filtered_countsNb.plot(kind='bar') #creating a bar graph
plt.xticks(rotation=45) #rotating the names on the x axis to a 45 degree angle to prevent overlap
plt.xlabel('Neighborhood Names') #labeling the x axis as Neighborhood Names
plt.ylabel('# of ballfields') #labeling the y axis as # of ballfields
plt.title('Ballfields') #titling the graph as Ballfields
plt.tight_layout() #adjusts the size of the graph to fit the 10,6 parameters

# %% [markdown]
# # My Conclusion

# %% [markdown]
# ### From my metric, the best choice would be Highland Park due to it having 6 ballfields. However, Brighton Heights and Mt. Oliver would also be good choices. Since my metric is such a vague part of describing family safeness and fun, my final thought was that if it is close enough to a neighborhood that is also safe, it would not be hard for families to walk there.
